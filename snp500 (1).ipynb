# %%
# !pip install yfinance
# Out:
# ...
#      |████████████████████████████████| 5.5MB 6.2MB/s
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.55-py2.py3-none-any.whl size=22616 sha256=3135cd9d0db64552fe7f9841d6eeebc1a6f97d5d68f2797a781aa9cc7e06ae95
#   Stored in directory: /root/.cache/pip/wheels/04/98/cc/2702a4242d60bdc14f48b4557c427ded1fe92aedf257d4565c
# Successfully built yfinance
# ...
#   Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ...

# %%
import yfinance as yf
import pandas as pd

# %%
df = yf.download('^DJI', start='2020-12-10', end='2021-02-07', interval='15m')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df
# Out:
#                                    Open          High  ...     Adj Close    Volume
# Datetime                                               ...
# 2020-12-10 09:30:00-05:00  30032.550781  30046.060547  ...  29968.060547  13161092
# 2020-12-10 09:45:00-05:00  29967.660156  30063.570312  ...  30046.529297  13985996
# 2020-12-10 10:00:00-05:00  30052.009766  30055.859375  ...  30021.519531  13631863
# 2020-12-10 10:15:00-05:00  30021.789062  30032.480469  ...  29995.970703  11581096
# 2020-12-10 10:30:00-05:00  29997.099609  30022.630859  ...  29999.589844  12308821
# ...                                 ...           ...  ...           ...       ...
# 2021-02-05 14:45:00-05:00  31147.720703  31150.230469  ...  31134.210938   7030567
# 2021-02-05 15:00:00-05:00  31134.359375  31134.359375  ...  31126.060547   8644081
# 2021-02-05 15:15:00-05:00  31126.519531  31148.150391  ...  31112.140625   8167898
# 2021-02-05 15:30:00-05:00  31112.320312  31142.269531  ...  31128.390625   9507956
# ...

# %%
df['MA200'] = df['Adj Close'].rolling(window=200).mean()

# %%
df = df.dropna()

# %%
df
# Out:
#                                    Open          High  ...    Volume         MA200
# Datetime                                               ...
# 2020-12-21 13:45:00-05:00  30269.439453  30269.439453  ...   8853723  30099.258184
# 2020-12-21 14:00:00-05:00  30238.740234  30246.380859  ...   8285314  30100.628135
# 2020-12-21 14:15:00-05:00  30241.060547  30281.000000  ...   7764916  30101.766387
# 2020-12-21 14:30:00-05:00  30273.929688  30304.140625  ...   8542288  30102.992236
# 2020-12-21 14:45:00-05:00  30266.880859  30279.240234  ...   7100601  30104.217480
# ...                                 ...           ...  ...       ...           ...
# 2021-02-05 14:45:00-05:00  31147.720703  31150.230469  ...   7030567  30648.931807
# 2021-02-05 15:00:00-05:00  31134.359375  31134.359375  ...   8644081  30651.576855
# 2021-02-05 15:15:00-05:00  31126.519531  31148.150391  ...   8167898  30653.875010
# 2021-02-05 15:30:00-05:00  31112.320312  31142.269531  ...   9507956  30656.523916
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(df['Adj Close'])
plt.plot(df['MA200'])
plt.show()

# %%
df['price change'] = df['Adj Close'].pct_change()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#                                    Open  ...  price change
# Datetime                                 ...
# 2020-12-21 13:45:00-05:00  30269.439453  ...           NaN
# 2020-12-21 14:00:00-05:00  30238.740234  ...      0.000121
# 2020-12-21 14:15:00-05:00  30241.060547  ...      0.001062
# 2020-12-21 14:30:00-05:00  30273.929688  ...     -0.000247
# 2020-12-21 14:45:00-05:00  30266.880859  ...     -0.000848
# ...                                 ...  ...           ...
# 2021-02-05 14:45:00-05:00  31147.720703  ...     -0.000438
# 2021-02-05 15:00:00-05:00  31134.359375  ...     -0.000262
# 2021-02-05 15:15:00-05:00  31126.519531  ...     -0.000447
# 2021-02-05 15:30:00-05:00  31112.320312  ...      0.000522
# 2021-02-05 15:45:00-05:00  31128.900391  ...      0.000435
#
# [804 rows x 8 columns]

# %%
df = df.dropna()

# %%
df
# Out:
#                                    Open  ...  price change
# Datetime                                 ...
# 2020-12-21 14:00:00-05:00  30238.740234  ...      0.000121
# 2020-12-21 14:15:00-05:00  30241.060547  ...      0.001062
# 2020-12-21 14:30:00-05:00  30273.929688  ...     -0.000247
# 2020-12-21 14:45:00-05:00  30266.880859  ...     -0.000848
# 2020-12-21 15:00:00-05:00  30241.150391  ...     -0.000485
# ...                                 ...  ...           ...
# 2021-02-05 14:45:00-05:00  31147.720703  ...     -0.000438
# 2021-02-05 15:00:00-05:00  31134.359375  ...     -0.000262
# 2021-02-05 15:15:00-05:00  31126.519531  ...     -0.000447
# 2021-02-05 15:30:00-05:00  31112.320312  ...      0.000522
# 2021-02-05 15:45:00-05:00  31128.900391  ...      0.000435
#
# [803 rows x 8 columns]

# %%
df['Upmove'] = df['price change'].apply(lambda x: x if x>0 else 0)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['Downmove'] = df['price change'].apply(lambda x: abs(x) if x<0 else 0)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['avg Up'] = df['Upmove'].ewm(span=19).mean()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['avg Down']= df['Downmove'].ewm(span=19).mean()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df = df.dropna()

# %%
df
# Out:
#                                    Open          High  ...    avg Up  avg Down
# Datetime                                               ...
# 2020-12-21 14:00:00-05:00  30238.740234  30246.380859  ...  0.000121  0.000000
# 2020-12-21 14:15:00-05:00  30241.060547  30281.000000  ...  0.000616  0.000000
# 2020-12-21 14:30:00-05:00  30273.929688  30304.140625  ...  0.000389  0.000091
# 2020-12-21 14:45:00-05:00  30266.880859  30279.240234  ...  0.000276  0.000311
# 2020-12-21 15:00:00-05:00  30241.150391  30257.029297  ...  0.000209  0.000354
# ...                                 ...           ...  ...       ...       ...
# 2021-02-05 14:45:00-05:00  31147.720703  31150.230469  ...  0.000289  0.000288
# 2021-02-05 15:00:00-05:00  31134.359375  31134.359375  ...  0.000260  0.000285
# 2021-02-05 15:15:00-05:00  31126.519531  31148.150391  ...  0.000234  0.000301
# 2021-02-05 15:30:00-05:00  31112.320312  31142.269531  ...  0.000263  0.000271
# ...

# %%
df['RS'] = df['avg Up']/df['avg Down']

# %%
df['RSI'] = df['RS'].apply(lambda x: 100-(100/(x+1)))

# %%
df
# Out:
#                                    Open          High  ...        RS         RSI
# Datetime                                               ...
# 2020-12-21 14:00:00-05:00  30238.740234  30246.380859  ...       inf  100.000000
# 2020-12-21 14:15:00-05:00  30241.060547  30281.000000  ...       inf  100.000000
# 2020-12-21 14:30:00-05:00  30273.929688  30304.140625  ...  4.260878   80.991764
# 2020-12-21 14:45:00-05:00  30266.880859  30279.240234  ...  0.886049   46.979103
# 2020-12-21 15:00:00-05:00  30241.150391  30257.029297  ...  0.589246   37.077087
# ...                                 ...           ...  ...       ...         ...
# 2021-02-05 14:45:00-05:00  31147.720703  31150.230469  ...  1.005313   50.132479
# 2021-02-05 15:00:00-05:00  31134.359375  31134.359375  ...  0.913051   47.727488
# 2021-02-05 15:15:00-05:00  31126.519531  31148.150391  ...  0.777594   43.744179
# 2021-02-05 15:30:00-05:00  31112.320312  31142.269531  ...  0.970114   49.241517
# ...

# %%
df.loc[(df['Adj Close'] > df['MA200']) & (df['RSI'] <30), 'Buy'] = 'Yes'

# %%
df.loc[(df['Adj Close'] < df['MA200']) | (df['RSI'] >30), 'Buy'] = 'No'

# %%
PnL = []

for i in range(len(df) - 12):
    if "Yes" in df['Buy'].iloc[i]:
        for j in range(1,11):
            if df['RSI'].iloc[i + j] > 40:
                PnL.append(df['Open'].iloc[i+j+1] - df['Open'].iloc[i+1])
                break
            elif j == 10:
                PnL.append(df['Open'].iloc[i+j+1] - df['Open'].iloc[i+1])

# %%
PnL
#plt.plot(PnL)
#plt.show()
# Out:
# [40.21875,
#  28.62109375,
#  96.279296875,
#  -306.80078125,
#  -194.111328125,
#  -191.0,
#  -66.169921875]

# %%
positive = 0
neg = 0
for i in range(len(PnL)):
  if i > 0:
    positive = positive + PnL[i]
  else:
    neg = neg+ abs(PnL[i])
print(positive)
print(neg)
# Out:
# -633.181640625
# 40.21875

# %%
len([i for i in PnL if i > 0])
# Out:
# 3

# %%
len(PnL)
# Out:
# 7

# %%
8/15
# Out:
# 0.5333333333333333

# %%
df.loc[df['Buy'] == 'Yes']
# Out:
#                                    Open          High  ...        RSI  Buy
# Datetime                                               ...
# 2020-12-21 15:30:00-05:00  30220.519531  30221.320312  ...  17.144420  Yes
# 2020-12-22 09:30:00-05:00  30200.199219  30200.199219  ...  27.093505  Yes
# 2021-01-08 13:30:00-05:00  30890.259766  30890.259766  ...  26.018832  Yes
# 2021-01-14 15:00:00-05:00  31098.429688  31114.339844  ...  27.825926  Yes
# 2021-01-14 15:15:00-05:00  31066.300781  31071.929688  ...  25.824521  Yes
# 2021-01-14 15:30:00-05:00  31054.710938  31077.679688  ...  25.480747  Yes
# 2021-01-14 15:45:00-05:00  31051.599609  31071.529297  ...  18.445388  Yes
#
# [7 rows x 15 columns]
